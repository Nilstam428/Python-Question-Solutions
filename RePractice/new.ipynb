# %%
! pip install plotly
! pip install ipython
! pip install --upgrade nbformat
# Out:
# Requirement already satisfied: plotly in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from plotly) (1.42.1)
# Requirement already satisfied: packaging in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: ipython in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (8.12.2)
# Requirement already satisfied: backcall in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing-extensions in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (4.12.2)
# Requirement already satisfied: colorama in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from stack-data->ipython) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from stack-data->ipython) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from stack-data->ipython) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Collecting nbformat
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from jsonschema>=2.6->nbformat) (6.4.5)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema>=2.6->nbformat)
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Downloading rpds_py-0.20.1-cp38-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (306)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\nilesh\anaconda3\envs\ai_calc\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat) (3.21.0)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.20.1-cp38-none-win_amd64.whl (218 kB)
# Installing collected packages: fastjsonschema, rpds-py, pkgutil-resolve-name, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed fastjsonschema-2.21.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 nbformat-5.10.4 pkgutil-resolve-name-1.3.10 referencing-0.35.1 rpds-py-0.20.1

# %%
    import pandas as pd
    import plotly.graph_objects as go

    label_list = ['cat', 'dog', 'domesticated', 'female', 'male', 'wild']
    # cat: 0, dog: 1, domesticated: 2, female: 3, male: 4, wild: 5
    source = [0, 0, 1, 3, 4, 4]
    target = [3, 4, 4, 2, 2, 5]
    count = [21, 6, 22, 21, 6, 22]

    fig = go.Figure(data=[go.Sankey(
        node = {"label": label_list},
        link = {"source": source, "target": target, "value": count}
        )])
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 14
#       8 count = [21, 6, 22, 21, 6, 22]
#      10 fig = go.Figure(data=[go.Sankey(
#      11     node = {"label": label_list},
#      12     link = {"source": source, "target": target, "value": count}
#      13     )])
# ---> 14 fig.show()
#
# File c:\Users\Nilesh\anaconda3\envs\ai_calc\lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)
#    3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Nilesh\anaconda3\envs\ai_calc\lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
