# %%
L1 = ['r','a','m']
l2 = "".join(L1)
print(l2)
print(type(l2))
# Out:
# ram
# <class 'str'>

# %%
name = 'Nilesh'
name_list = list(name)
print(name_list)
# Out:
# ['N', 'i', 'l', 'e', 's', 'h']

# %%
names = ['nilesh', 'sandeep', 'jaiprakash', 'manoj']
age = [23,22,23,21]
person = {}
for person_name in names:
    person = person.keys
for ages in age:
    value = ages
print(person)
print(person.type)
print(person_name.type)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       3 person = {}
#       4 for person_name in names:
# ----> 5     person.keys = person
#       6 for ages in age:
#       7     person.values = ages
#
# AttributeError: 'dict' object attribute 'keys' is read-only
